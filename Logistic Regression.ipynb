# %% [markdown]
# # Logistic Regression

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("Refactored_Py_DS_ML_Bootcamp-master/13-Logistic-Regression/titanic_train.csv")
test = pd.read_csv("Refactored_Py_DS_ML_Bootcamp-master/13-Logistic-Regression/titanic_test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False)

# %% [markdown]
# ## Check ratio of classes

# %%
sns.countplot(x='Survived', hue='Sex', data=train)

# %%
sns.countplot(x='Survived', hue='Pclass', data=train)

# %%
sns.distplot(train['Age'].dropna()) #seems bimodal

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='SibSp', data=train)

# %%
train['Fare'].hist(bins=40, figsize=(10,4))

# %% [markdown]
# ## Cleaning our data

# %% [markdown]
# ### Imputing missing data using a smart scheme of correlating age with passenger class

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Pclass', y='Age', data=train)

# %%
def impute_age(cols):
    Age = cols[0]
    Pclass = cols[1]

    if pd.isnull(Age):
        if Pclass == 1:
            return 37
        elif Pclass == 2:
            return 29
        else:
            return 24
    else:
        return Age

# %%
train['Age'] = train[['Age', 'Pclass']].apply(impute_age, axis=1)

# %%
sns.heatmap(train.isnull(), yticklabels=False)

# %%
train.drop('Cabin', axis=1, inplace=True)

# %%
train.dropna(inplace=True)

# %% [markdown]
# ### Changing to categorical

# %%
sex = pd.get_dummies(train['Sex'], drop_first=True) #male is a perfect predictor of female because its 1 or 0 so we use drop_first

# %%
embark = pd.get_dummies(train['Embarked'], drop_first=True)

# %%
train = pd.concat([train, sex, embark], axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  male  Q  S
# 0      0         A/5 21171   7.2500        S     1  0  1
# 1      0          PC 17599  71.2833        C     0  0  0
# 2      0  STON/O2. 3101282   7.9250        S     0  0  1
# 3      0            113803  53.1000        S     0  0  1
# ...

# %% [markdown]
# ### Dropping unused columns

# %%
train.drop(['Sex', 'Embarked', 'Name', 'Ticket'], axis=1, inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0       3  22.0      1      0   7.2500     1  0  1
# 1            2         1       1  38.0      1      0  71.2833     0  0  0
# 2            3         1       3  26.0      0      0   7.9250     0  0  1
# 3            4         1       1  35.0      1      0  53.1000     0  0  1
# 4            5         0       3  35.0      0      0   8.0500     1  0  1

# %%
train.drop(['PassengerId'], axis=1, inplace=True)

# %% [markdown]
# ### Training and building model

# %% [markdown]
# ### Splitting into train test

# %%
x = train.drop('Survived', axis=1)
y = train['Survived']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
lm = LogisticRegression()
lm.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = lm.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       163
#            1       0.82      0.71      0.76       104
#
#     accuracy                           0.83       267
#    macro avg       0.83      0.81      0.81       267
# weighted avg       0.83      0.83      0.83       267

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[147,  16],
#        [ 30,  74]])
